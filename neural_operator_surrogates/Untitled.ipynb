# %%
# !python train_all_operators.py
# Out:
# ...
# Running experiment: fno_fractional_laplacian
# Task: fractional_laplacian
# Model: fno
# ...
# PyTorch compilation enabled for better performance
# epoch=0001 train_mse=2.268848e-01 val_mse=2.679732e-03 val_rel_l2=5.175424e-02 best_epoch=0001 patience=0/50
# epoch=0010 train_mse=1.813168e-05 val_mse=1.579096e-05 val_rel_l2=3.711621e-03 best_epoch=0009 patience=1/50
# epoch=0020 train_mse=1.099589e-05 val_mse=1.165482e-05 val_rel_l2=3.282978e-03 best_epoch=0009 patience=11/50
# epoch=0030 train_mse=3.030634e-05 val_mse=3.721692e-05 val_rel_l2=5.933343e-03 best_epoch=0026 patience=4/50
# epoch=0040 train_mse=1.029157e-05 val_mse=7.931191e-06 val_rel_l2=2.735994e-03 best_epoch=0026 patience=14/50
# epoch=0050 train_mse=7.834147e-06 val_mse=7.137672e-06 val_rel_l2=2.528700e-03 best_epoch=0026 patience=24/50
# epoch=0060 train_mse=3.744420e-05 val_mse=9.559158e-06 val_rel_l2=2.980712e-03 best_epoch=0026 patience=34/50
# ...
