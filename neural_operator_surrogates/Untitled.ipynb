# %%
# !python train_operator.py
# Out:
# ...
# Running experiment: fno_fractional_laplacian
# Task: fractional_laplacian
# Model: fno
# ...
# PyTorch compilation enabled for better performance
# epoch=0001 train_mse=2.204826e-01 val_mse=2.216847e-03 val_rel_l2=4.791000e-02 best_epoch=0001 patience=0/50
