# %%
# !python train_all_operators.py
# Out:
# ...
# Running experiment: fno_fractional_laplacian
# Task: fractional_laplacian
# Model: fno
# ...
# PyTorch compilation enabled for better performance
# epoch=0001 train_mse=4.227768e-01 val_mse=5.200289e-03 val_rel_l2=5.228205e-02 best_epoch=0001 patience=0/50
# epoch=0010 train_mse=3.904259e-05 val_mse=3.199378e-05 val_rel_l2=3.922598e-03 best_epoch=0010 patience=0/50
# epoch=0020 train_mse=2.159509e-05 val_mse=1.951155e-05 val_rel_l2=3.122425e-03 best_epoch=0017 patience=3/50
# epoch=0030 train_mse=6.963775e-05 val_mse=6.095511e-05 val_rel_l2=5.774790e-03 best_epoch=0017 patience=13/50
# epoch=0040 train_mse=6.792051e-05 val_mse=4.619402e-05 val_rel_l2=5.110221e-03 best_epoch=0017 patience=23/50
# epoch=0050 train_mse=1.413452e-05 val_mse=1.354951e-05 val_rel_l2=2.622126e-03 best_epoch=0017 patience=33/50
# epoch=0060 train_mse=2.159612e-04 val_mse=2.905826e-05 val_rel_l2=3.903830e-03 best_epoch=0017 patience=43/50
# Early stopping at epoch 67. Best epoch: 17, best val MSE: 2.127776e-05
# ...
